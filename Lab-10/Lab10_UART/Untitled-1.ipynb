# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
headers = ['Voltage']
df = pd.read_csv('capture.txt', names=headers)
df['Voltage'] /= 1000
df
# Out:
#     Voltage
# 0     2.345
# 1     2.477
# 2     2.603
# 3     2.706
# 4     2.796
# ..      ...
# 66    2.603
# 67    2.480
# 68    2.348
# 69    2.196
# 70    0.002
#
# [71 rows x 1 columns]

# %%
df.plot(y = 'Voltage', use_index = True)
# Out:
# <AxesSubplot: >
